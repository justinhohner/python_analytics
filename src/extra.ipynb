# %%
import pandas as pd
import seaborn as sb

orders_df = pd.read_csv('data/superstore_orders.csv', parse_dates=['Order Date', 'Ship Date'])

#orders_df.corr()
pearsoncorr = orders_df.corr(method='pearson')
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)

# %%
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

scatter_matrix(orders_df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120bb0ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11efeae90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f02b6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f05ded0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f0a1710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f0d5f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f117750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f14cf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f155d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f196710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f2017d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f236fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f278810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f2b7e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f2ec850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f32ce50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f360890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f3a1e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f3d78d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f417ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f44a910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f48df10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f4c3950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f502f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f538990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f578f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f5ad9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f5eefd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f621a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f663250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f697a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f6d8290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f70ea90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f74d2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f780ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f7c3310>]],
#       dtype=object)
